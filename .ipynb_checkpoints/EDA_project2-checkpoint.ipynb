# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### IMPORTING DATASET

# %%
data=pd.read_csv('aidataset.csv')
df=pd.DataFrame(data)
df
# Out:
#         job_id                 job_title  salary_usd salary_currency  \
# 0      AI00001            Data Scientist      219728             USD
# 1      AI00002                Head of AI      230237             JPY
# 2      AI00003             Data Engineer      128890             EUR
# 3      AI00004  Computer Vision Engineer       96349             USD
# 4      AI00005         Robotics Engineer       63065             EUR
# ...        ...                       ...         ...             ...
# 14995  AI14996        AI Product Manager       39171             USD
# 14996  AI14997        AI Product Manager       77555             EUR
# 14997  AI14998             Data Engineer       28380             USD
# 14998  AI14999             AI Specialist       58764             EUR
# 14999  AI15000  Principal Data Scientist       58623             USD
#
#        salary_local experience_level employment_type company_location  \
# ...

# %%
df.shape
# Out:
# (15000, 22)

# %%
df.columns
# Out:
# Index(['job_id', 'job_title', 'salary_usd', 'salary_currency', 'salary_local',
#        'experience_level', 'employment_type', 'company_location',
#        'company_size', 'employee_residence', 'remote_ratio', 'required_skills',
#        'education_required', 'years_experience', 'industry', 'posting_date',
#        'application_deadline', 'job_description_length', 'benefits_score',
#        'company_name'],
#       dtype='object')

# %%
df.describe()
# Out:
#           salary_usd  salary_local  remote_ratio  years_experience  \
# count   15000.000000  1.500000e+04  15000.000000      15000.000000
# mean   121991.938267  8.292366e+05     50.196667          6.365667
# std     63968.361846  3.425325e+06     40.844084          5.598551
# min     16621.000000  1.662100e+04      0.000000          0.000000
# 25%     74978.500000  7.383075e+04      0.000000          2.000000
# 50%    107261.500000  1.090355e+05     50.000000          5.000000
# 75%    155752.250000  1.673278e+05    100.000000         10.000000
# max    410273.000000  3.368541e+07    100.000000         19.000000
#
#        job_description_length  benefits_score
# count            15000.000000    15000.000000
# mean              1500.852600        7.499540
# std                574.724647        1.444202
# min                500.000000        5.000000
# 25%                998.750000        6.300000
# 50%               1512.000000        7.500000
# ...

# %%
df.tail()
# Out:
#         job_id                 job_title  salary_usd salary_currency  \
# 14995  AI14996        AI Product Manager       39171             USD
# 14996  AI14997        AI Product Manager       77555             EUR
# 14997  AI14998             Data Engineer       28380             USD
# 14998  AI14999             AI Specialist       58764             EUR
# 14999  AI15000  Principal Data Scientist       58623             USD
#
#        salary_local experience_level employment_type company_location  \
# 14995         39171               MI              CT            China
# 14996         65922               EN              CT      Netherlands
# 14997         28380               EN              FL            India
# 14998         49949               EN              PT           France
# 14999         58623               SE              FT            China
#
#       company_size employee_residence  remote_ratio  \
# 14995            M              China            50
# ...

# %% [markdown]
# #### CLEAN DATA

# %%
df.isnull().sum()
# Out:
# job_id                    0
# job_title                 0
# salary_usd                0
# salary_currency           0
# salary_local              0
# experience_level          0
# employment_type           0
# company_location          0
# company_size              0
# employee_residence        0
# remote_ratio              0
# required_skills           0
# education_required        0
# years_experience          0
# industry                  0
# posting_date              0
# application_deadline      0
# job_description_length    0
# benefits_score            0
# company_name              0
# dtype: int64

# %%
df.isna().sum()
# Out:
# job_id                    0
# job_title                 0
# salary_usd                0
# salary_currency           0
# salary_local              0
# experience_level          0
# employment_type           0
# company_location          0
# company_size              0
# employee_residence        0
# remote_ratio              0
# required_skills           0
# education_required        0
# years_experience          0
# industry                  0
# posting_date              0
# application_deadline      0
# job_description_length    0
# benefits_score            0
# company_name              0
# dtype: int64

# %%
df['Joining_date'] = pd.to_datetime(df['date'], dayfirst=True) # dayfirst= pandas work in mm/dd/yyyy format but the datset has dd/mm/yyyy
df.head(2)
# Out:
#     job_id       job_title  salary_usd salary_currency  salary_local  \
# 0  AI00001  Data Scientist      219728             USD        219728
# 1  AI00002      Head of AI      230237             JPY      25326070
#
#   experience_level employment_type company_location company_size  \
# 0               EX              PT           Sweden            M
# 1               EX              PT            Japan            L
#
#   employee_residence  ...  education_required years_experience  \
# 0             Sweden  ...           Associate               13
# 1              Japan  ...            Bachelor               10
#
#          industry  posting_date application_deadline job_description_length  \
# 0  Transportation    23-09-2024           31-10-2024                   1132
# 1  Transportation    26-07-2024           12-09-2024                   2299
#
#   benefits_score        company_name       date Joining_date
# 0            6.6        TechCorp Inc 2024-09-23   2024-09-23
# ...

# %%
df['application_deadline']=pd.to_datetime(df['application_deadline'],dayfirst=True)
df.head(2)
# Out:
#     job_id       job_title  salary_usd salary_currency  salary_local  \
# 0  AI00001  Data Scientist      219728             USD        219728
# 1  AI00002      Head of AI      230237             JPY      25326070
#
#   experience_level employment_type company_location company_size  \
# 0               EX              PT           Sweden            M
# 1               EX              PT            Japan            L
#
#   employee_residence  ...  education_required years_experience  \
# 0             Sweden  ...           Associate               13
# 1              Japan  ...            Bachelor               10
#
#          industry  posting_date application_deadline job_description_length  \
# 0  Transportation    23-09-2024           2024-10-31                   1132
# 1  Transportation    26-07-2024           2024-09-12                   2299
#
#   benefits_score        company_name       date Joining_date
# 0            6.6        TechCorp Inc 2024-09-23   2024-09-23
# ...

# %%
df['job_id'].unique()
# Out:
# array(['AI00001', 'AI00002', 'AI00003', ..., 'AI14998', 'AI14999',
#        'AI15000'], shape=(15000,), dtype=object)
