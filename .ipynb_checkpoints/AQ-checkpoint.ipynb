# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### IMPORTING A DATASET

# %%
data=pd.read_csv('AirQualityUCI.csv')
df=pd.DataFrame(data)
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10-03-2004  18.00.00     2.6         1360       150      11.9
# 1     10-03-2004  19.00.00     2.0         1292       112       9.4
# 2     10-03-2004  20.00.00     2.2         1402        88       9.0
# 3     10-03-2004  21.00.00     2.2         1376        80       9.2
# 4     10-03-2004  22.00.00     1.6         1272        51       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04-04-2005  10.00.00     3.1         1314      -200      13.5
# 9353  04-04-2005  11.00.00     2.4         1163      -200      11.4
# 9354  04-04-2005  12.00.00     2.4         1142      -200      12.4
# 9355  04-04-2005  13.00.00     2.1         1003      -200       9.5
# 9356  04-04-2005  14.00.00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   int64
#  4   NMHC(GT)       9357 non-null   int64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   int64
#  7   NOx(GT)        9357 non-null   int64
#  8   PT08.S3(NOx)   9357 non-null   int64
#  9   NO2(GT)        9357 non-null   int64
#  10  PT08.S4(NO2)   9357 non-null   int64
#  11  PT08.S5(O3)    9357 non-null   int64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %%
df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10-03-2004  18.00.00     2.6         1360       150      11.9
# 1  10-03-2004  19.00.00     2.0         1292       112       9.4
# 2  10-03-2004  20.00.00     2.2         1402        88       9.0
# 3  10-03-2004  21.00.00     2.2         1376        80       9.2
# 4  10-03-2004  22.00.00     1.6         1272        51       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
# 2            939      131          1140      114          1555         1074
# 3            948      172          1092      122          1584         1203
# 4            836      131          1205      116          1490         1110
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
df.tail()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9352  04-04-2005  10.00.00     3.1         1314      -200      13.5
# 9353  04-04-2005  11.00.00     2.4         1163      -200      11.4
# 9354  04-04-2005  12.00.00     2.4         1142      -200      12.4
# 9355  04-04-2005  13.00.00     2.1         1003      -200       9.5
# 9356  04-04-2005  14.00.00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352           1101      472           539      190          1374
# 9353           1027      353           604      179          1264
# 9354           1063      293           603      175          1241
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3)     T    RH      AH
# 9352         1729  21.9  29.3  0.7568
# 9353         1269  24.3  23.7  0.7119
# 9354         1092  26.9  18.3  0.6406
# ...

# %% [markdown]
# #### CLEAN DATA

# %%
# time is in hh.mm.ss format actual format is hh:mm:ss
# to convert time to the format using
# regex false gives a instruction to pandas to treat only dots and replace it
df['Time']=df['Time'].str.replace('.',':',regex= False)
df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10-03-2004  18:00:00     2.6         1360       150      11.9
# 1  10-03-2004  19:00:00     2.0         1292       112       9.4
# 2  10-03-2004  20:00:00     2.2         1402        88       9.0
# 3  10-03-2004  21:00:00     2.2         1376        80       9.2
# 4  10-03-2004  22:00:00     1.6         1272        51       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
# 2            939      131          1140      114          1555         1074
# 3            948      172          1092      122          1584         1203
# 4            836      131          1205      116          1490         1110
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
# date and time 
df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], dayfirst=True) # dayfirst= pandas work in mm/dd/yyyy format but the datset has dd/mm/yyyy
df.head(2)
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10-03-2004  18:00:00     2.6         1360       150      11.9
# 1  10-03-2004  19:00:00     2.0         1292       112       9.4
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
#
#       T    RH      AH            DateTime
# 0  13.6  48.9  0.7578 2004-03-10 18:00:00
# 1  13.3  47.7  0.7255 2004-03-10 19:00:00

# %%
df['Day']=df['DateTime'].dt.day_name()
df.head(2)
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10-03-2004  18:00:00     2.6         1360       150      11.9
# 1  10-03-2004  19:00:00     2.0         1292       112       9.4
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
#
#       T    RH      AH            DateTime        Day
# 0  13.6  48.9  0.7578 2004-03-10 18:00:00  Wednesday
# 1  13.3  47.7  0.7255 2004-03-10 19:00:00  Wednesday

# %% [markdown]
# #### HANDLING MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# DateTime         0
# Day              0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# DateTime         0
# Day              0
# dtype: int64

# %%
# pollution values or any values should not be negative and that value is treated as missing value
df['CO(GT)'].value_counts()
# Out:
# CO(GT)
# -200.0    1683
#  1.0       305
#  1.4       279
#  1.6       275
#  1.5       273
#           ...
#  10.1        1
#  9.9         1
#  9.4         1
#  9.3         1
#  8.5         1
# Name: count, Length: 97, dtype: int64

# %%
print(df['CO(GT)'].unique())
# Out:
# [ 2.60e+00  2.00e+00  2.20e+00  1.60e+00  1.20e+00  1.00e+00  9.00e-01
#   6.00e-01 -2.00e+02  7.00e-01  1.10e+00  1.70e+00  1.50e+00  1.90e+00
#   2.90e+00  4.80e+00  6.90e+00  6.10e+00  3.90e+00  1.40e+00  8.00e-01
#   4.40e+00  3.10e+00  2.70e+00  2.10e+00  2.50e+00  2.80e+00  2.40e+00
#   3.70e+00  6.60e+00  3.50e+00  5.40e+00  3.20e+00  4.10e+00  3.60e+00
#   2.30e+00  4.20e+00  1.80e+00  3.00e+00  4.60e+00  5.90e+00  3.40e+00
#   5.50e+00  8.10e+00  5.80e+00  8.00e+00  6.50e+00  1.30e+00  5.30e+00
#   3.30e+00  4.00e+00  3.80e+00  5.10e+00  5.00e-01  4.30e+00  5.00e+00
#   7.60e+00  6.70e+00  5.70e+00  4.70e+00  4.50e+00  6.20e+00  4.00e-01
#   3.00e-01  5.20e+00  4.90e+00  6.30e+00  7.30e+00  6.40e+00  6.00e+00
#   5.60e+00  7.20e+00  2.00e-01  1.00e-01  7.50e+00  7.00e+00  7.70e+00
#   6.80e+00  8.40e+00  7.90e+00  9.50e+00  9.20e+00  8.70e+00  7.80e+00
#   1.02e+01  8.30e+00  8.60e+00  1.19e+01  1.15e+01  1.01e+01  9.40e+00
# ...

# %%
df.replace(-200,pd.NA,inplace=True)
df.isna().sum().sort_values(ascending=False)
# Out:
# NMHC(GT)         8443
# CO(GT)           1683
# NO2(GT)          1642
# NOx(GT)          1639
# RH                366
# PT08.S2(NMHC)     366
# C6H6(GT)          366
# PT08.S3(NOx)      366
# PT08.S1(CO)       366
# AH                366
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# Date                0
# Time                0
# DateTime            0
# Day                 0
# dtype: int64

# %% [markdown]
# | Method       | Use Case                                         | Example                                     |
# | ------------ | ------------------------------------------------ | ------------------------------------------- |
# | `linear`     | Time series with smooth trend (default and safe) | ✅                                           |
# | `time`       | When index is a datetime and intervals vary      | Best for irregular time data                |
# | `polynomial` | When data curves more than straight line         | `interpolate(method='polynomial', order=2)` |
# | `spline`     | Smooth curves, use for gentle variations         | `interpolate(method='spline', order=2)`     |
# | `nearest`    | Fill using nearest known value                   | For categorical-like sequences              |
# | `ffill`      | Fill from the previous value                     | When trends stay flat for a while           |
# | `bfill`      | Fill from the next value                         | Similar to ffill                            |

# %% [markdown]
# #### first identify the use case
# 1. If the line is smooth and gently rising/falling, use linear.
# 2. If the data curves, try spline or polynomial.
# 3. If values stay flat for a while, use ffill.

# %%
# error will come if we plot directly since we are having non numeric value NAN
# so concverting non nyumeric junk to real nan values
# with coerce invalid entries becomes nan
df = df.apply(pd.to_numeric, errors='coerce')

# %%
df['CO(GT)'].plot(figsize=(12,4), title='CO Levels Over Time')
plt.show()

# %%
df['NO2(GT)'].plot(figsize=(12,4),title="NO2 Levels over Time",color="Green")
plt.show()

# %%
df['NOx(GT)'].plot(figsize=(12,4),color="yellow",title="NO Levels over time")
plt.show()

# %%
df['C6H6(GT)'].plot(figsize=(12,4),color="pink",title="ozone Levels over time")
plt.show()

# %%
df['CO(GT)'] = df['CO(GT)'].interpolate() # used interpolate to remove nan values 
df['CO(GT)'].isna().sum()
# Out:
# np.int64(0)

# %%
df['CO(GT)'].plot(figsize=(12,4), title='CO Levels Over Time')
plt.show()

# %%
plt.bar(df['CO(GT)'],df['NO2(GT)'],color="Green")
# Out:
# <BarContainer object of 9357 artists>
